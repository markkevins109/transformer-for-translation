# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from pylab import rcParams
import matplotlib.pyplot as plt
import warnings
from mlxtend.plotting import plot_decision_regions
from matplotlib.colors import ListedColormap
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout, Dense
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_circles
import seaborn as sns

# %%
X, y = make_circles(n_samples=100, noise=0.1, random_state=1)
y_categorical = np.where(y == 0, 'Class 0', 'Class 1')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=2)

# %%
y_train.shape
# Out:
# (80,)

# %%
model = Sequential()
model.add(Dense(256, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model without early stopping
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=3500, verbose=0)

# Plot loss history
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Model Loss Without Early Stopping')
plt.legend()
plt.show()

# %%
model = Sequential()

model.add(Dense(256, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
callback = EarlyStopping(
    monitor="val_loss",
    min_delta=0.00001,
    patience=20,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=False
)

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=3500, callbacks=callback)
# Out:
# Epoch 1/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 0.4953 - loss: 0.6895 - val_accuracy: 0.5000 - val_loss: 0.6969
# Epoch 2/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4938 - loss: 0.6864 - val_accuracy: 0.4500 - val_loss: 0.6995
# Epoch 3/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5008 - loss: 0.6893 - val_accuracy: 0.4500 - val_loss: 0.7012
# Epoch 4/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5320 - loss: 0.6858 - val_accuracy: 0.4000 - val_loss: 0.7036
# Epoch 5/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5328 - loss: 0.6876 - val_accuracy: 0.4000 - val_loss: 0.7050
# Epoch 6/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5367 - loss: 0.6856 - val_accuracy: 0.4000 - val_loss: 0.7065
# Epoch 7/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5484 - loss: 0.6850 - val_accuracy: 0.4000 - val_loss: 0.7079
# Epoch 8/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5562 - loss: 0.6836 - val_accuracy: 0.4000 - val_loss: 0.7100
# Epoch 9/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5547 - loss: 0.6840 - val_accuracy: 0.4000 - val_loss: 0.7117
# Epoch 10/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5641 - loss: 0.6811 - val_accuracy: 0.4000 - val_loss: 0.7140
# Epoch 11/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5742 - loss: 0.6793 - val_accuracy: 0.4000 - val_loss: 0.7163
# Epoch 12/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6273 - loss: 0.6725 - val_accuracy: 0.4000 - val_loss: 0.7178
# Epoch 13/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5742 - loss: 0.6794 - val_accuracy: 0.3500 - val_loss: 0.7180
# Epoch 14/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5742 - loss: 0.6801 - val_accuracy: 0.3500 - val_loss: 0.7177
# Epoch 15/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5781 - loss: 0.6762 - val_accuracy: 0.3500 - val_loss: 0.7175
# Epoch 16/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5820 - loss: 0.6761 - val_accuracy: 0.3500 - val_loss: 0.7170
# Epoch 17/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5719 - loss: 0.6751 - val_accuracy: 0.4000 - val_loss: 0.7162
# Epoch 18/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5117 - loss: 0.6814 - val_accuracy: 0.4000 - val_loss: 0.7154
# Epoch 19/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5664 - loss: 0.6761 - val_accuracy: 0.4000 - val_loss: 0.7146
# Epoch 20/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5844 - loss: 0.6747 - val_accuracy: 0.4000 - val_loss: 0.7141
# Epoch 21/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5609 - loss: 0.6778 - val_accuracy: 0.4000 - val_loss: 0.7137
# Epoch 21: early stopping

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()
